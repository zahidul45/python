# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Zahidul Islam\\Downloads\\m35 (1).csv")

# %%
df
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 0                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4                7.2022   ASTRA ZENECA     7/2/2022  M350776
# ...                 ...            ...          ...      ...
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 0                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# 1                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# ...

# %%
df.head(10)
# Out:
#    Cal. year / month Material Group Calendar Day Material  \
# 0             7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1             7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2             7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3             7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4             7.2022   ASTRA ZENECA     7/2/2022  M350776
# 5             7.2022   ASTRA ZENECA     7/2/2022  M350776
# 6             7.2022   ASTRA ZENECA     7/2/2022  M350776
# 7             7.2022   ASTRA ZENECA     7/2/2022  M350800
# 8             7.2022   ASTRA ZENECA     7/2/2022  M350800
# 9             7.2022   ASTRA ZENECA     7/2/2022  M350800
#
#                       Brand         Sales Office Sales District  \
# 0  FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off          Dubai
# 1  FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off    Deira Dubai
# 2   FORXIGA 5MG TABS OF 28S  MPC Dubai Sales Off          Dubai
# 3   FORXIGA 5MG TABS OF 28S  MPC Dubai Sales Off    Deira Dubai
# ...

# %%
df.tail(10)
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 4907             7.2022   ASTRA ZENECA    7/29/2022  M360118
# 4908             7.2022   ASTRA ZENECA    7/29/2022  M360118
# 4909             7.2022   ASTRA ZENECA    7/29/2022  M360118
# 4910             7.2022   ASTRA ZENECA    7/29/2022  M360118
# 4911             7.2022   ASTRA ZENECA    7/29/2022  M360118
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 4907       PULMICORT NEB.SOL OF 0.5MG OF 20'S  MPC Dubai Sales Off
# 4908       PULMICORT NEB.SOL OF 0.5MG OF 20'S  MPC Dubai Sales Off
# 4909       PULMICORT NEB.SOL OF 0.5MG OF 20'S     MPC Abudhabi Off
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4917 entries, 0 to 4916
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Cal. year / month  4917 non-null   float64
#  1   Material Group     4917 non-null   object
#  2   Calendar Day       4917 non-null   object
#  3   Material           4917 non-null   object
#  4   Brand              4917 non-null   object
#  5   Sales Office       4917 non-null   object
#  6   Sales District     4917 non-null   object
#  7   Sold-to party      4917 non-null   int64
#  8   Acounts            4917 non-null   object
#  9   Ship-To Party      4917 non-null   int64
#  10  Customer group 1   4917 non-null   object
#  11  SalesValue         4896 non-null   object
#  12  SalesQty           4896 non-null   object
#  13  FocQty             304 non-null    object
#  14  Total Qty(Ea)      4917 non-null   object
# dtypes: float64(1), int64(2), object(12)
# ...

# %%
df.isnull().sum()
# Out:
# Cal. year / month       0
# Material Group          0
# Calendar Day            0
# Material                0
# Brand                   0
# Sales Office            0
# Sales District          0
# Sold-to party           0
# Acounts                 0
# Ship-To Party           0
# Customer group 1        0
# SalesValue             21
# SalesQty               21
# FocQty               4613
# Total Qty(Ea)           0
# dtype: int64

# %%
df.isnull()
# Out:
#       Cal. year / month  Material Group  Calendar Day  Material  Brand  \
# 0                 False           False         False     False  False
# 1                 False           False         False     False  False
# 2                 False           False         False     False  False
# 3                 False           False         False     False  False
# 4                 False           False         False     False  False
# ...                 ...             ...           ...       ...    ...
# 4912              False           False         False     False  False
# 4913              False           False         False     False  False
# 4914              False           False         False     False  False
# 4915              False           False         False     False  False
# 4916              False           False         False     False  False
#
#       Sales Office  Sales District  Sold-to party  Acounts  Ship-To Party  \
# ...

# %%
df.columns
# Out:
# Index(['Cal. year / month', 'Material Group', 'Calendar Day', 'Material',
#        'Brand', 'Sales Office', 'Sales District', 'Sold-to party', 'Acounts',
#        'Ship-To Party', 'Customer group 1', 'SalesValue', 'SalesQty', 'FocQty',
#        'Total Qty(Ea)'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Cal. year / month  Sold-to party  Ship-To Party
# count       4.917000e+03    4917.000000   4.917000e+03
# mean        7.202200e+00   68585.625381   4.542651e+06
# std         2.380560e-13   39142.366879   6.674247e+07
# min         7.202200e+00     157.000000   1.570000e+02
# 25%         7.202200e+00   45851.000000   4.585200e+04
# 50%         7.202200e+00   75560.000000   7.586800e+04
# 75%         7.202200e+00  104769.000000   1.050200e+05
# max         7.202200e+00  124728.000000   1.000001e+09

# %%
df.describe().transpose()
# Out:
#                     count          mean           std       min         25%  \
# Cal. year / month  4917.0  7.202200e+00  2.380560e-13    7.2022      7.2022
# Sold-to party      4917.0  6.858563e+04  3.914237e+04  157.0000  45851.0000
# Ship-To Party      4917.0  4.542651e+06  6.674247e+07  157.0000  45852.0000
#
#                           50%          75%           max
# Cal. year / month      7.2022       7.2022  7.202200e+00
# Sold-to party      75560.0000  104769.0000  1.247280e+05
# Ship-To Party      75868.0000  105020.0000  1.000001e+09

# %%
lf = pd.read_csv("C:\\Users\\Zahidul Islam\\Downloads\\tips.csv")

# %%
lf
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %%
lf['tip%']= df['tip']/df['total_bill']*100

# %%
lf.head(15)
# Out:
#     total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0        16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1        10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2        21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3        23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4        24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5        25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6         8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7        26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8        15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9        14.78  3.23    Male     No  Sun  Dinner     2              7.39
# 10       10.27  1.71    Male     No  Sun  Dinner     2              5.14
# 11       35.26  5.00  Female     No  Sun  Dinner     4              8.82
# ...

# %%
lf[lf['total_bill']>40]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
#
#           Payer Name     CC Number Payment ID       tip%
# 59       Brian Ortiz  6.600000e+15    Sat8139  13.942407
# ...

# %%
lf[lf['total_bill']>40].count()
# Out:
# total_bill          10
# tip                 10
# sex                 10
# smoker              10
# day                 10
# time                10
# size                10
# price_per_person    10
# Payer Name          10
# CC Number           10
# Payment ID          10
# tip%                10
# dtype: int64

# %%
lf['total_bill']<25
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 239    False
# 240    False
# 241     True
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
lf[lf['sex']=='Male']
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 1         10.34  1.66  Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50  Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31  Male     No  Sun  Dinner     2             11.84
# 5         25.29  4.71  Male     No  Sun  Dinner     4              6.32
# 6          8.77  2.00  Male     No  Sun  Dinner     2              4.38
# ..          ...   ...   ...    ...  ...     ...   ...               ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2              6.30
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2             16.42
# 239       29.03  5.92  Male     No  Sat  Dinner     3              9.68
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75  Male     No  Sat  Dinner     2              8.91
#
#              Payer Name     CC Number Payment ID       tip%
# ...

# %%
lf[lf['sex']=='Male'].count()
# Out:
# total_bill          157
# tip                 157
# sex                 157
# smoker              157
# day                 157
# time                157
# size                157
# price_per_person    157
# Payer Name          157
# CC Number           157
# Payment ID          157
# tip%                157
# dtype: int64

# %%
lf.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number  \
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563313e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369139e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040000e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525000e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.552500e+15
# max     50.810000   10.000000    6.000000         20.270000  6.600000e+15
#
#              tip%
# count  244.000000
# mean    16.080258
# std      6.107220
# min      3.563814
# 25%     12.912736
# 50%     15.476977
# 75%     19.147549
# max     71.034483

# %%
df['SalesValue(AED)']= df['SalesValue']

# %%
df
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 0                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4                7.2022   ASTRA ZENECA     7/2/2022  M350776
# ...                 ...            ...          ...      ...
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 0                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# 1                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# ...

# %%
df
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 0                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4                7.2022   ASTRA ZENECA     7/2/2022  M350776
# ...                 ...            ...          ...      ...
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 0                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# 1                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# ...

# %%
df = df.drop("SalesValue", axis=1)

# %%
df
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 0                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4                7.2022   ASTRA ZENECA     7/2/2022  M350776
# ...                 ...            ...          ...      ...
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 0                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# 1                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# ...

# %%
df['SalesQty(ABD)']= df['SalesQty']

# %%
df
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 0                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4                7.2022   ASTRA ZENECA     7/2/2022  M350776
# ...                 ...            ...          ...      ...
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 0                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# 1                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# ...

# %%
df = pd.DataFrame.from_dict({
    'Name': ['Nik', 'Kate', 'Evan', 'Kyra'],
    'Age': [31, 30, 40, 33],
    'Location': ['Toronto', 'London', 'Kingston', 'Hamilton']
})

# %%
df = pd.read_csv("C:\\Users\\Zahidul Islam\\Downloads\\m35 (1).csv")

# %%
df
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 0                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4                7.2022   ASTRA ZENECA     7/2/2022  M350776
# ...                 ...            ...          ...      ...
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 0                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# 1                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# ...

# %%
df.rename(columns = {'Acounts':'Acounts Name'})
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 0                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4                7.2022   ASTRA ZENECA     7/2/2022  M350776
# ...                 ...            ...          ...      ...
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 0                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# 1                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# ...

# %%
df.columns.str.lower()
df
# Out:
#       Cal. year / month Material Group Calendar Day Material  \
# 0                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 1                7.2022   ASTRA ZENECA     7/2/2022  M350764
# 2                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 3                7.2022   ASTRA ZENECA     7/2/2022  M350765
# 4                7.2022   ASTRA ZENECA     7/2/2022  M350776
# ...                 ...            ...          ...      ...
# 4912             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4913             7.2022   ASTRA ZENECA    7/29/2022  M360182
# 4914             7.2022   ASTRA ZENECA    7/29/2022  M360202
# 4915             7.2022   ASTRA ZENECA    7/31/2022  M360047
# 4916             7.2022   ASTRA ZENECA    7/31/2022  M360048
#
#                                         Brand         Sales Office  \
# 0                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# 1                    FORXIGA 10MG TABS OF 28S  MPC Dubai Sales Off
# ...
