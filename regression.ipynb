# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Zahidul Islam\\Downloads\\Regression-Part-1.csv")

# %%
df
# Out:
#     Moisture    Fat  TBARS  Texture  Fat Uptake  Batter Viscosity  \
# 0      51.32  28.96   2.72   239.42       22.33            351.50
# 1      52.61  18.25   3.34   287.07       11.62            351.50
# 2      53.33  13.68   2.87   285.65        7.05            440.90
# 3      52.79  11.76   2.54   378.82        5.13            440.90
# 4      52.61  13.91   4.02   357.37        7.28            351.50
# 5      53.97  14.29   4.11   223.30        7.66            440.90
# 6      54.49  16.28   3.42   317.32        9.65            734.00
# 7      54.30  25.25   2.49   221.04       18.62            440.90
# 8      56.72  15.74   3.42   303.31        9.11           1228.00
# 9      56.68  18.25   3.34   264.34       11.62           1228.00
# 10     58.17  18.25   3.34   287.07       11.62           1228.00
# 11     66.78  18.25   3.34   287.07       11.62           1228.00
# 12     58.25  18.25   3.34   287.07       11.62           1228.00
# ...

# %%
df.head()
# Out:
#    Moisture    Fat  TBARS  Texture  Fat Uptake  Batter Viscosity  \
# 0     51.32  28.96   2.72   239.42       22.33             351.5
# 1     52.61  18.25   3.34   287.07       11.62             351.5
# 2     53.33  13.68   2.87   285.65        7.05             440.9
# 3     52.79  11.76   2.54   378.82        5.13             440.9
# 4     52.61  13.91   4.02   357.37        7.28             351.5
#
#    Oleogel Viscosity  Canola Oil Viscosity
# 0               25.6                  25.2
# 1               30.8                  28.4
# 2               36.0                  28.6
# 3               34.8                  28.8
# 4               29.2                  29.8

# %%
sns.scatterplot(x='Moisture',y='Canola Oil Viscosity',data=df)
# Out:
# <Axes: xlabel='Moisture', ylabel='Canola Oil Viscosity'>

# %%
df.describe()
# Out:
#         Moisture        Fat      TBARS     Texture  Fat Uptake  \
# count  22.000000  22.000000  22.000000   22.000000   22.000000
# mean   55.045000  18.176364   3.347727  287.458182   11.546364
# std     3.510698   4.917451   0.479086   39.335735    4.917451
# min    47.520000  11.760000   2.490000  216.700000    5.130000
# 25%    53.490000  14.937500   3.340000  286.005000    8.307500
# 50%    54.640000  17.750000   3.340000  287.070000   11.120000
# 75%    56.300000  18.250000   3.420000  301.265000   11.620000
# max    66.780000  32.670000   4.620000  378.820000   26.040000
#
#        Batter Viscosity  Oleogel Viscosity  Canola Oil Viscosity
# count         22.000000          22.000000             22.000000
# mean         726.673636          53.078636             33.958182
# std          320.057032          21.791258              4.644819
# min          351.500000          25.200000             25.200000
# 25%          440.900000          35.550000             32.900000
# ...

# %%
df.corr()
# Out:
#                       Moisture       Fat     TBARS   Texture  Fat Uptake  \
# Moisture              1.000000 -0.326347 -0.175353  0.143039   -0.326347
# Fat                  -0.326347  1.000000  0.150348 -0.724974    1.000000
# TBARS                -0.175353  0.150348  1.000000 -0.190180    0.150348
# Texture               0.143039 -0.724974 -0.190180  1.000000   -0.724974
# Fat Uptake           -0.326347  1.000000  0.150348 -0.724974    1.000000
# Batter Viscosity      0.782015 -0.208635 -0.022148  0.101835   -0.208635
# Oleogel Viscosity     0.854542 -0.199135 -0.057630  0.087589   -0.199135
# Canola Oil Viscosity  0.258073 -0.122542  0.201110  0.026758   -0.122542
#
#                       Batter Viscosity  Oleogel Viscosity  \
# Moisture                      0.782015           0.854542
# Fat                          -0.208635          -0.199135
# TBARS                        -0.022148          -0.057630
# Texture                       0.101835           0.087589
# ...

# %%
plt.figure(figsize=(14,8),dpi=150)
sns.heatmap(df.corr(),annot=True,cmap="cividis")
plt.savefig('part-2.png')
